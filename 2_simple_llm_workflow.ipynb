# %%
from langgraph.graph import StateGraph ,START ,END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(model="gemini-flash-latest" , temperature=0)

# %%
# create a state 

class LLMState(TypedDict):

    question : str
    answer : str

# %%
def llm_qa(state : LLMState) -> LLMState:

    # extract thye question from state
    question = state['question']

    # form a prompt
    prompt = f'Answer the following{question}'

    # ask the question to the llm
    answer = model.invoke(prompt).content

    # update the answer in the state 
    state['answer'] = answer

    return state

# %%
# create our graph

graph = StateGraph(LLMState)

# add node
graph.add_node('llm_qa' , llm_qa)

# add eges
graph.add_edge(START , 'llm_qa')
graph.add_edge('llm_qa' , END)

# compile 
workflow = graph.compile()

# %%
# execute 

initial_state = {'question':'How far is  sun from the earth?'}

final_state = workflow.invoke(initial_state)
print(final_state['answer'])
# Out:
# [{'type': 'text', 'text': "On average, the Sun is about **93 million miles** (**150 million kilometers**) away from the Earth. \n\nBecause the Earth’s orbit around the Sun is not a perfect circle but an ellipse (oval-shaped), this distance changes throughout the year:\n\n* **Closest point (Perihelion):** About **91.4 million miles** (147 million km) in early January.\n* **Farthest point (Aphelion):** About **94.5 million miles** (152 million km) in early July.\n\n### Two interesting ways to think about this distance:\n1. **Astronomical Unit (AU):** This average distance is so fundamental to astronomy that scientists use it as a standard unit of measurement called 1 Astronomical Unit (AU). \n2. **Speed of Light:** Light travels at 186,282 miles per second. Even at that incredible speed, it takes about **8 minutes and 20 seconds** for light from the Sun to reach Earth. If the Sun were to suddenly go dark, we wouldn't know it for over 8 minutes!", 'extras': {'signature': '...'}}]
